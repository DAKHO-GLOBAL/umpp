# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy.exc import SQLAlchemyError

# Configuration de la base de données
db_config = {
    "host": "localhost",
    "user": "root",
    "password": "",
    "database": "pmu_ia",
    "port": "3306",
}

# Connexion à la base de données MySQL
engine = create_engine(f"mysql+mysqlconnector://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}")

# Créer les métadonnées sans 'bind'
metadata = MetaData()

# Fonction pour récupérer 2 lignes de chaque table
def get_two_rows_per_table(engine):
    connection = engine.connect()
    result = {}

    # Parcourir toutes les tables de la base de données
    metadata.reflect(bind=engine)  # Réfléchir les métadonnées en liant l'engine
    for table_name in metadata.tables:
        table = metadata.tables[table_name]
        try:
            query = table.select().limit(2)  # Sélectionner 2 lignes maximum
            rows = connection.execute(query).fetchall()
            
            # Ajouter les résultats dans le dictionnaire
            result[table_name] = rows
        except SQLAlchemyError as e:
            print(f"Erreur lors de la récupération des données pour la table {table_name}: {str(e)}")
    
    connection.close()
    return result

# Appel de la fonction pour récupérer les données
rows_per_table = get_two_rows_per_table(engine)

# Afficher les résultats
for table_name, rows in rows_per_table.items():
    print(f"Table: {table_name}")
    for row in rows:
        print(row)
    print('-' * 50)
# Out:
# Table: chevaux
# Colonnes: id, nom, age, sexe, proprietaire, nomPere, nomMere, created_at
# Table: commentaires_course
# Colonnes: id, id_course, texte, source
# Table: pmu_courses
# Colonnes: id, numReunion, numExterneReunion, numOrdre, numExterne, libelle, libelleCourt, heureDepart, timezoneOffset, distance, distanceUnit, corde, nombreDeclaresPartants, discipline, specialite, hippodrome_code, ordreArrivee, statut, categorieStatut, dureeCourse, reunion_id, categorieParticularite, conditionSexe, montantPrix, created_at
# Table: pmu_hippodromes
# Colonnes: code, libelleCourt, libelleLong
# Table: pmu_reunions
# Colonnes: id, cached, timezoneOffset, dateReunion, numOfficiel, numOfficielReunionPrecedente, numOfficielReunionSuivante, numExterne, nature, audience, statut, disciplinesMere, specialites, derniereReunion, reportPlusFpaMax, hippodrome_code, pays_code, nebulositeCode, nebulositeLibelleCourt, nebulositeLibelleLong, temperature, forceVent, directionVent, created_at
# Table: pmu_pays
# Colonnes: code, libelle
# Table: cote_historique
# Colonnes: id, id_participation, horodatage, cote
# Table: participations
# Colonnes: id, id_course, id_cheval, id_jockey, position, poids, est_forfait, cote_initiale, cote_actuelle, statut, numPmu, created_at
# Table: courses
# Colonnes: id, date_heure, lieu, type_course, distance, terrain, num_course, libelle, corde, ordreArrivee, created_at, pmu_course_id
# Table: jockeys
# Colonnes: id, nom, pays, created_at
# Table: incidents
# Colonnes: id, id_course, type_incident, numero_participants
# Table: model_versions
# Colonnes: id, model_type, hyperparameters, training_date, training_duration, accuracy, precision_score, recall_score, f1_score, log_loss, file_path, training_data_range, feature_count, sample_count, validation_method, notes, is_active, created_at, updated_at
# Table: photos_arrivee
# Colonnes: id, id_course, url, height, width, is_original
# Table: pmu_cote_evolution
# Colonnes: id, id_participant, horodatage, cote, variation
# Table: pmu_participants
# Colonnes: id, id_course, numPmu, nom, age, sexe, race, statut, driver, jockey, entraineur, proprietaire, musique, incident, ordreArrivee, tempsObtenu, reductionKilometrique, dernierRapportDirect, dernierRapportReference, handicapPoids, nomPere, nomMere, created_at, cheval_id, jockey_id
# Table: predictions
# Colonnes: id, id_course, horodatage, prediction, note_confiance, model_version_id
# Table: chevaux
# (1, 'ZVALIKOVA', 3, 'FEMELLES', 'E.CONOIR', 'LE HAVRE', 'ZVALINSKA', datetime.datetime(2025, 4, 6, 15, 3, 16))
# (2, 'CORTADO', 3, 'MALES', 'STALL RITTERBUSCH', 'HOLY ROMAN EMPEROR', 'COVE BEACH', datetime.datetime(2025, 4, 6, 15, 3, 16))
# --------------------------------------------------
# Table: commentaires_course
# --------------------------------------------------
# Table: pmu_courses
# (1, 1, None, 1, 1, 'GRAND PRIX DU CENTRE EST - GONTRAN DE NO', 'GP CENTRE EST', datetime.datetime(2024, 9, 18, 11, 55), 7200000, 2850, 'METRE', 'CORDE_GAUCHE', 14, 'ATTELE', 'TROT_ATTELE', None, '[[14], [3], [12], [11], [7], [6], [13], [10], [5], [9], [4], [2]]', 'FIN_COURSE', 'ARRIVEE', 203810, None, 'INTERNATIONALE', 'TOUS_CHEVAUX', 100000, datetime.datetime(2025, 4, 6, 15, 3, 14))
# (2, 1, None, 2, 2, 'GSF - PRIX DU CROISE-LAROCHE', 'GSF', datetime.datetime(2024, 9, 18, 12, 31), 7200000, 2850, 'METRE', 'CORDE_GAUCHE', 16, 'ATTELE', 'TROT_ATTELE', None, '[[15], [11], [10], [9], [8], [14], [5], [2], [1]]', 'FIN_COURSE', 'ARRIVEE', 218110, None, 'NATIONALE', 'TOUS_CHEVAUX', 21000, datetime.datetime(2025, 4, 6, 15, 3, 16))
# --------------------------------------------------
# Table: pmu_hippodromes
# ('A30', 'KALGOORLIE AUSTRALIE', 'HIPPODROME DE KALGOORLIE AUSTRALIE')
# ('AMI', 'AMIENS', "HIPPODROME D'AMIENS")
# --------------------------------------------------
# Table: pmu_reunions
# (1, None, None, datetime.datetime(2024, 9, 17, 22, 0), 1, None, None, 1, 'DIURNE', 'NATIONAL', 'TERMINEE', None, None, None, None, 'LYO', 'FRA', 'P4', 'Peu Nuageux', "Le soleil l'emportera et les nuages resteront discrets.", 21, 5, 'N', datetime.datetime(2025, 4, 6, 15, 3, 14))
# (2, None, None, datetime.datetime(2024, 9, 17, 22, 0), 2, None, None, 2, 'DIURNE', 'NATIONAL', 'TERMINEE', None, None, None, None, 'HAM', 'DEU', 'P4', 'Peu Nuageux', "Le soleil l'emportera et les nuages resteront discrets.", 24, 12, 'NE', datetime.datetime(2025, 4, 6, 15, 3, 30))
# --------------------------------------------------
# Table: pmu_pays
# ('AAA', 'Indetermine')
# ('ARG', 'Argentine')
# --------------------------------------------------
# Table: cote_historique
# --------------------------------------------------
# Table: participations
# (1, 1, 1, 1, 13, 600.0, 0, 19.0, 30.0, 'PARTANT', 1, datetime.datetime(2025, 4, 6, 15, 3, 16))
# (2, 1, 2, 2, 10, 600.0, 0, 17.0, 19.0, 'PARTANT', 2, datetime.datetime(2025, 4, 6, 15, 3, 16))
# --------------------------------------------------
# Table: courses
# (1, datetime.datetime(2024, 9, 18, 11, 55), 'HIPPODROME DE LYON-PARILLY', 'TROT_ATTELE', 2850, '', 1, 'GRAND PRIX DU CENTRE EST - GONTRAN DE NO', None, None, datetime.datetime(2025, 4, 6, 15, 3, 14), 1)
# (2, datetime.datetime(2024, 9, 18, 12, 31), 'HIPPODROME DE LYON-PARILLY', 'TROT_ATTELE', 2850, '', 2, 'GSF - PRIX DU CROISE-LAROCHE', None, None, datetime.datetime(2025, 4, 6, 15, 3, 16), 2)
# --------------------------------------------------
# Table: jockeys
# (1, 'C.LECOEUVRE', '', datetime.datetime(2025, 4, 6, 15, 3, 16))
# (2, 'H.BOUTIN', '', datetime.datetime(2025, 4, 6, 15, 3, 16))
# --------------------------------------------------
# Table: incidents
# (1, 1, 'DISQUALIFIE_POUR_ALLURE_IRREGULIERE', '"[1, 8]"')
# (2, 2, 'DISQUALIFIE_POUR_ALLURE_IRREGULIERE', '"[3, 4, 6, 7, 12, 13, 16]"')
# --------------------------------------------------
# Table: model_versions
# --------------------------------------------------
# Table: photos_arrivee
# (1, 1, 'https://www.pmu.fr/back-assets/hippique/infocentre/photos/arrivee/18092024R1C1/photo_arrivee_450px_width_size.jpg', 217, 450, 0)
# (2, 1, 'https://www.pmu.fr/back-assets/hippique/infocentre/photos/arrivee/18092024R1C1/photo_arrivee_200px_width_size.jpg', 96, 200, 0)
# --------------------------------------------------
# Table: pmu_cote_evolution
# --------------------------------------------------
# Table: pmu_participants
# (1, 1, 1, 'ZVALIKOVA', 3, 'FEMELLES', 'PUR-SANG', 'PARTANT', 'C.LECOEUVRE', None, 'A.FOUASSIER', 'E.CONOIR', '2p0p7p1p(23)3p3p3p1p2p', None, 13, None, None, '{"typePari": "E_SIMPLE_GAGNANT", "rapport": 30.0, "typeRapport": "DIRECT", "indicateurTendance": " ", "nombreIndicateurTendance": 0.0, "dateRapport": 1726574271000, "permutation": 1, "favoris": false, "numPmu1": 1, "grossePrise": false}', '{"typePari": "E_SIMPLE_GAGNANT", "rapport": 19.0, "typeRapport": "REFERENCE", "indicateurTendance": "-", "nombreIndicateurTendance": -7.92, "dateRapport": 1726572305000, "permutation": 1, "favoris": false, "numPmu1": 1, "grossePrise": false}', 600.0, None, None, datetime.datetime(2025, 4, 6, 15, 3, 16), 1, 1)
# (2, 1, 2, 'CORTADO', 3, 'MALES', 'PUR-SANG', 'PARTANT', 'H.BOUTIN', None, 'A.SUBORICS', 'STALL RITTERBUSCH', '3p7p5p9p6p5p2p(23)1p', None, 10, None, None, '{"typePari": "E_SIMPLE_GAGNANT", "rapport": 19.0, "typeRapport": "DIRECT", "indicateurTendance": " ", "nombreIndicateurTendance": 0.0, "dateRapport": 1726574271000, "permutation": 1, "favoris": false, "numPmu1": 2, "grossePrise": false}', '{"typePari": "E_SIMPLE_GAGNANT", "rapport": 17.0, "typeRapport": "REFERENCE", "indicateurTendance": "-", "nombreIndicateurTendance": -1.72, "dateRapport": 1726572305000, "permutation": 1, "favoris": false, "numPmu1": 2, "grossePrise": false}', 600.0, None, None, datetime.datetime(2025, 4, 6, 15, 3, 16), 2, 2)
# --------------------------------------------------
# Table: predictions
# --------------------------------------------------
